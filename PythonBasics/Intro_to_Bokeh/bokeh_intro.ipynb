# %% [markdown]
# ### Making a Bokeh Line

# %%
from bokeh.plotting import figure
from bokeh.io import output_file, show

# %%
# Parameter data
x = [1, 2, 3, 4, 5]
y = [6, 7, 8, 9, 10]

# %%
# Prepare the output file
output_file('resources/Line.html')

# Create a figure object
f = figure()

# %%
# Create a line plot
f.line(x, y)

# Show the line
show(f)
